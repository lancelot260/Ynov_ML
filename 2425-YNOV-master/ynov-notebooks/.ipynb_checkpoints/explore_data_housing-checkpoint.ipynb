# %%
import pandas as pd

# %%
train_data = pd.read_csv("../ynov-data/train_housing.csv")

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1627.0           280.0
# 4        -122.25     37.85                52.0        919.0           213.0
# ...          ...       ...                 ...          ...             ...
# 11995    -121.43     39.18                36.0       1124.0           184.0
# 11996    -121.48     39.10                19.0       2043.0           421.0
# 11997    -121.45     39.26                15.0       2319.0           416.0
# 11998    -121.53     39.19                27.0       2080.0           412.0
# 11999    -121.56     39.27                28.0       2332.0           395.0
#
# ...

# %%
train_data.median_income.hist()
# Out:
# <Axes: >

# %%
train_data.median_house_value.hist()

# %%
# !pip install autoviz
# Out:
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 11.3 MB/s eta 0:00:0031m11.0 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 MB 14.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.3/626.3 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 15.6 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# ...
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# ...
#   Attempting uninstall: xgboost
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# Initialisation
av = AutoViz_Class()
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
# Générer le rapport
df = av.AutoViz("../ynov-data/train_housing.csv")
# Out:
# Shape of your Data Set loaded: (12000, 11)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  9
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     11 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['id']
# ...

# %%
# Afficher le rapport
report.show_html("rapport_sweetviz.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Afficher le rapport
# ----> 2 report.show_html("rapport_sweetviz.html")
#
# NameError: name 'report' is not defined

# %%
# !pip install lux-api
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 19.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 1.2 MB/s eta 0:00:0033.5 MB/s eta 0:00:01
# ...
#   Created wheel for lux-api: filename=lux_api-0.5.1-py3-none-any.whl size=185606 sha256=682d5d98e8b1ce55d3c68c36b54a2797024493a2e0f47ca412cc92ebc81cd7aa
#   Stored in directory: /Users/FRANCOIS/Library/Caches/pip/wheels/29/2f/f5/d5fcd3111309d380314ce9ad7ed6eb2fe03b3315123bd0c2e9
# ...
#   Created wheel for lux-widget: filename=lux_widget-0.1.11-py3-none-any.whl size=2540454 sha256=a37e52bea93b9cdeb1c5ad437eeef72594f8a50e8b11cf177dfdc84cfe297e3f
# ...

# %%
import pandas as pd
import lux


# Activer Lux
df  # Affichera des recommandations visuelles
